# %% [markdown]
# # 1. Fonksiyonlar

# %% [markdown]
# ## 1.1 void fonksiyon

# %%
"""
isim = input("İsminizi öğrenebilir miyim? ")
print(f"Hoşgeldin {isim}")

isim = input("İsminizi öğrenebilir miyim? ")
print(f"Hoşgeldin {isim}")

isim = input("İsminizi öğrenebilir miyim? ")
print(f"Hoşgeldin {isim}")

isim = input("İsminizi öğrenebilir miyim? ")
print(f"Hoşgeldin {isim}")

isim = input("İsminizi öğrenebilir miyim? ")
print(f"Hoşgeldin {isim}")

isim = input("İsminizi öğrenebilir miyim? ")
print(f"Hoşgeldin {isim}")
"""

def hosgeldin():
    print("Hoşgeldin")
   
hosgeldin()
hosgeldin()
hosgeldin()
hosgeldin()
hosgeldin()
hosgeldin()
# Out:
# Hoşgeldin
# Hoşgeldin
# Hoşgeldin
# Hoşgeldin
# Hoşgeldin
# Hoşgeldin

# %%
def hosgeldin(ad):
    print("Hoşgeldin ",ad)
    
hosgeldin("Ceyhun")
hosgeldin("Ali")
isim = input("İsminizi öğrenebilir miyim? ")
hosgeldin(isim)
# Out:
# Hoşgeldin  Ceyhun
# Hoşgeldin  Ali
# İsminizi öğrenebilir miyim? Mert
# Hoşgeldin  Mert

# %%
def hosgeldin(ad,soyad):
    print("Hoşgeldin ",ad,soyad)
    
isim = input("İsminizi öğrenebilir miyim? ")
soyisim = input("Soyadınızı öğrenebilir miyim? ")

hosgeldin(isim,soyisim)
# Out:
# İsminizi öğrenebilir miyim? Ceyhun
# Soyadınızı öğrenebilir miyim? Özdemir
# Hoşgeldin  Ceyhun Özdemir

# %%
def hosgeldin(ad = "Yazılmadı",soyad = "Yazılmadı"):
    print("Hoşgeldin ",ad,soyad)
    
isim = input("İsminizi öğrenebilir miyim? ")
soyisim = input("Soyadınızı öğrenebilir miyim? ")

hosgeldin(isim,soyisim)
# Out:
# İsminizi öğrenebilir miyim? Ceyhun
# Soyadınızı öğrenebilir miyim? Özdemir
# Hoşgeldin  Ceyhun Özdemir

# %%
selam = hosgeldin
selam("Ceyhun","Özdemir")
# Out:
# Hoşgeldin  Ceyhun Özdemir

# %% [markdown]
# ## 1.2 Argümanlar *args

# %%
def calisan(*bilgiler):
    print("Çalışan için girilen bilgiler şunlardır: ")
    for i in bilgiler:
        print(i)

calisan("Mert","Yılmaz","1990","İstanbul","Mert","Yılmaz","1990","İstanbul")
# Out:
# Çalışan için girilen bilgiler şunlardır:
# Mert
# Yılmaz
# 1990
# İstanbul
# Mert
# Yılmaz
# 1990
# İstanbul

# %% [markdown]
# ## 1.3 Keyword Argümanları **kwargs

# %%
def calisan(**bilgiler):
    print("Soyadı :",bilgiler["soyad"])
    print("Adı :",bilgiler["ad"])
    print("Doğum Tarihi :",bilgiler["dogum_tarihi"])
    print("Şehir :",bilgiler["sehir"])

calisan(ad="Ali",soyad="Korkmaz",dogum_tarihi=1995,sehir="İstanbul")
# Out:
# Soyadı : Korkmaz
# Adı : Ali
# Doğum Tarihi : 1995
# Şehir : İstanbul

# %% [markdown]
# ## 1.4 return

# %%
def topla(x,y):
    toplam = x+y
    
    return toplam
    
sonuc = topla(3,4)
print(sonuc)
# Out:
# 7

# %% [markdown]
# ## 1.5 pass

# %%
def fonksiyon():
    pass

# %% [markdown]
# ## 1.6 Lambda

# %%
#def topla(x,y):
#    return x+y

topla = lambda x,y : x + y
topla(4,5)

carp = lambda x,y,z : x * y * z
carp(2,3,6)
# Out:
# 36

# %% [markdown]
# # 2. Modüller

# %% [markdown]
# ## 2.1 Python'ın İçindeki Modüller

# %%
import math
#dir(math)
#help(math)

math.sqrt(16)

def karekök(x):
    return x**(0.5)
karekök(16)
# Out:
# 4.0

# %%
import math as matematik
matematik.sqrt(16)
# Out:
# 4.0

# %%
from math import sqrt,factorial
factorial(5)
# Out:
# 120

# %%
from math import factorial as faktöriyel
faktöriyel(4)
# Out:
# 24

# %% [markdown]
# ## 2.2 Kendi Yazdığım Modül

# %% [markdown]
# 1- Modülümü python/lib klasörüne atacağım
#
# 2- Aynı klasörde olacak

# %% [markdown]
# # 3. Hatalar

# %% [markdown]
# ## 3.1 try, except, else, finally

# %%
try:
    print(x)
except NameError:
    print("NameError hatası aldım")
except ValueError:
    print("ValueError hatası aldım")
except:
    print("tanımadığım bir hata aldım")

    

print("Devam")
# Out:
# NameError hatası aldım

# %%
try:
    print(x)
except NameError:
    print("NameError hatası aldım")
except ValueError:
    print("ValueError hatası aldım")
except:
    print("tanımadığım bir hata aldım")

    

print("Devam")

# %%
try:
    print(x)
except NameError:
    print("NameError hatası aldım")
except ValueError:
    print("ValueError hatası aldım")
except:
    print("tanımadığım bir hata aldım")
else:
    print("Her şey yolunda")

# %%
try:
    print(x)
except NameError:
    print("NameError hatası aldım")
except ValueError:
    print("ValueError hatası aldım")
except:
    print("tanımadığım bir hata aldım")
else:
    print("Her şey yolunda")
finally:
    print("Ne olursa ol devam et")
# Out:
# NameError hatası aldım
# Ne olursa ol devam et

# %% [markdown]
# ## 3.2 Hata Türleri

# %% [markdown]
# https://docs.python.org/3/library/exceptions.html

# %% [markdown]
# ## 3.3 raise

# %%
x = -1

if x < 0:
    raise ValueError("x sıfırdan küçük")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-72-bb1f60240f1f> in <module>
#       2
#       3 if x < 0:
# ----> 4     raise ValueError("x sıfırdan küçük")
#
# ValueError: x sıfırdan küçük

# %%
sayı = 3
try:
    for i in sayı:
        print(i)
except TypeErrssor:
    print("Bir hata ile karşılaşıldı.")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-1541e038f65e> in <module>
#       2 try:
# ----> 3     for i in sayı:
#       4         print(i)
#
# TypeError: 'int' object is not iterable
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-1541e038f65e> in <module>
#       3     for i in sayı:
#       4         print(i)
# ----> 5 except TypeErrssor:
#       6     print("Bir hata ile karşılaşıldı.")
#
# NameError: name 'TypeErrssor' is not defined
